# %% [markdown]
# # Relatório de Análise VI

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/aluguel_residencial.csv', sep = ';')

# %%
dados.head(10)
# Out:
#                  Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0           Quitinete       Copacabana        1      0       0    40   1700.0
# 1                Casa  Jardim Botânico        2      0       1   100   7000.0
# 2         Apartamento           Centro        1      0       0    15    800.0
# 3         Apartamento     Higienópolis        1      0       0    48    800.0
# 4         Apartamento     Vista Alegre        3      1       0    70   1200.0
# 5         Apartamento         Cachambi        2      0       0    50   1300.0
# 6  Casa de Condomínio  Barra da Tijuca        5      4       5   750  22000.0
# 7  Casa de Condomínio            Ramos        2      2       0    65   1000.0
# 8         Apartamento           Centro        1      0       0    36   1200.0
# 9         Apartamento           Grajaú        2      1       0    70   1500.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 2       390.0  20.0
# 3       230.0   NaN
# 4         NaN   NaN
# 5       301.0  17.0
# 6         NaN   NaN
# 7         NaN   NaN
# 8         NaN   NaN
# 9       642.0  74.0

# %%
dados['Valor Bruto'] = dados['Valor'] + dados['Condominio'] + dados['IPTU']

# %%
dados.head(10)
# Out:
#                  Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0           Quitinete       Copacabana        1      0       0    40   1700.0
# 1                Casa  Jardim Botânico        2      0       1   100   7000.0
# 2         Apartamento           Centro        1      0       0    15    800.0
# 3         Apartamento     Higienópolis        1      0       0    48    800.0
# 4         Apartamento     Vista Alegre        3      1       0    70   1200.0
# 5         Apartamento         Cachambi        2      0       0    50   1300.0
# 6  Casa de Condomínio  Barra da Tijuca        5      4       5   750  22000.0
# 7  Casa de Condomínio            Ramos        2      2       0    65   1000.0
# 8         Apartamento           Centro        1      0       0    36   1200.0
# 9         Apartamento           Grajaú        2      1       0    70   1500.0
#
#    Condominio  IPTU  Valor Bruto
# 0       500.0  60.0       2260.0
# 1         NaN   NaN          NaN
# 2       390.0  20.0       1210.0
# 3       230.0   NaN          NaN
# 4         NaN   NaN          NaN
# 5       301.0  17.0       1618.0
# 6         NaN   NaN          NaN
# 7         NaN   NaN          NaN
# 8         NaN   NaN          NaN
# 9       642.0  74.0       2216.0

# %%
dados['Valor m2'] = dados['Valor'] / dados['Area']

# %%
dados.head(10)
# Out:
#                  Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0           Quitinete       Copacabana        1      0       0    40   1700.0
# 1                Casa  Jardim Botânico        2      0       1   100   7000.0
# 2         Apartamento           Centro        1      0       0    15    800.0
# 3         Apartamento     Higienópolis        1      0       0    48    800.0
# 4         Apartamento     Vista Alegre        3      1       0    70   1200.0
# 5         Apartamento         Cachambi        2      0       0    50   1300.0
# 6  Casa de Condomínio  Barra da Tijuca        5      4       5   750  22000.0
# 7  Casa de Condomínio            Ramos        2      2       0    65   1000.0
# 8         Apartamento           Centro        1      0       0    36   1200.0
# 9         Apartamento           Grajaú        2      1       0    70   1500.0
#
#    Condominio  IPTU  Valor Bruto   Valor m2
# 0       500.0  60.0       2260.0  42.500000
# 1         NaN   NaN          NaN  70.000000
# 2       390.0  20.0       1210.0  53.333333
# 3       230.0   NaN          NaN  16.666667
# 4         NaN   NaN          NaN  17.142857
# 5       301.0  17.0       1618.0  26.000000
# 6         NaN   NaN          NaN  29.333333
# 7         NaN   NaN          NaN  15.384615
# 8         NaN   NaN          NaN  33.333333
# 9       642.0  74.0       2216.0  21.428571

# %%
dados['Valor m2'] = dados['Valor m2'].round(2)

# %%
dados.head(10)
# Out:
#                  Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0           Quitinete       Copacabana        1      0       0    40   1700.0
# 1                Casa  Jardim Botânico        2      0       1   100   7000.0
# 2         Apartamento           Centro        1      0       0    15    800.0
# 3         Apartamento     Higienópolis        1      0       0    48    800.0
# 4         Apartamento     Vista Alegre        3      1       0    70   1200.0
# 5         Apartamento         Cachambi        2      0       0    50   1300.0
# 6  Casa de Condomínio  Barra da Tijuca        5      4       5   750  22000.0
# 7  Casa de Condomínio            Ramos        2      2       0    65   1000.0
# 8         Apartamento           Centro        1      0       0    36   1200.0
# 9         Apartamento           Grajaú        2      1       0    70   1500.0
#
#    Condominio  IPTU  Valor Bruto  Valor m2
# 0       500.0  60.0       2260.0     42.50
# 1         NaN   NaN          NaN     70.00
# 2       390.0  20.0       1210.0     53.33
# 3       230.0   NaN          NaN     16.67
# 4         NaN   NaN          NaN     17.14
# 5       301.0  17.0       1618.0     26.00
# 6         NaN   NaN          NaN     29.33
# 7         NaN   NaN          NaN     15.38
# 8         NaN   NaN          NaN     33.33
# 9       642.0  74.0       2216.0     21.43

# %%
dados_new = dados.copy()

# %%
dados_new
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites   Valor  \
# 0        Quitinete            Copacabana        1      0       0  1700.0
# 1             Casa       Jardim Botânico        2      0       1  7000.0
# 2      Apartamento                Centro        1      0       0   800.0
# 3      Apartamento          Higienópolis        1      0       0   800.0
# 4      Apartamento          Vista Alegre        3      1       0  1200.0
# ...            ...                   ...      ...    ...     ...     ...
# 22575  Apartamento                 Méier        2      0       0   900.0
# 22576    Quitinete                Centro        0      0       0   800.0
# 22577  Apartamento           Jacarepaguá        3      1       2  1800.0
# 22578  Apartamento  São Francisco Xavier        2      1       0  1400.0
# 22579  Apartamento                Leblon        2      0       0  3000.0
#
#        Condominio  IPTU  Valor Bruto  Valor m2
# 0           500.0  60.0       2260.0     42.50
# 1             NaN   NaN          NaN     70.00
# 2           390.0  20.0       1210.0     53.33
# 3           230.0   NaN          NaN     16.67
# 4             NaN   NaN          NaN     17.14
# ...           ...   ...          ...       ...
# 22575       490.0  48.0       1438.0     12.86
# 22576       350.0  25.0       1175.0     29.63
# 22577       800.0  40.0       2640.0     23.08
# 22578       509.0  37.0       1946.0     29.17
# 22579       760.0   NaN          NaN     42.86
#
# [22580 rows x 10 columns]

# %%
del dados_new['Vagas']

# %%
dados_new
# Out:
#               Tipo                Bairro  Quartos  Suites   Valor  Condominio  \
# 0        Quitinete            Copacabana        1       0  1700.0       500.0
# 1             Casa       Jardim Botânico        2       1  7000.0         NaN
# 2      Apartamento                Centro        1       0   800.0       390.0
# 3      Apartamento          Higienópolis        1       0   800.0       230.0
# 4      Apartamento          Vista Alegre        3       0  1200.0         NaN
# ...            ...                   ...      ...     ...     ...         ...
# 22575  Apartamento                 Méier        2       0   900.0       490.0
# 22576    Quitinete                Centro        0       0   800.0       350.0
# 22577  Apartamento           Jacarepaguá        3       2  1800.0       800.0
# 22578  Apartamento  São Francisco Xavier        2       0  1400.0       509.0
# 22579  Apartamento                Leblon        2       0  3000.0       760.0
#
#        IPTU  Valor Bruto  Valor m2
# 0      60.0       2260.0     42.50
# 1       NaN          NaN     70.00
# 2      20.0       1210.0     53.33
# 3       NaN          NaN     16.67
# 4       NaN          NaN     17.14
# ...     ...          ...       ...
# 22575  48.0       1438.0     12.86
# 22576  25.0       1175.0     29.63
# 22577  40.0       2640.0     23.08
# 22578  37.0       1946.0     29.17
# 22579   NaN          NaN     42.86
#
# [22580 rows x 9 columns]

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites   Valor  \
# 0        Quitinete            Copacabana        1      0       0  1700.0
# 1             Casa       Jardim Botânico        2      0       1  7000.0
# 2      Apartamento                Centro        1      0       0   800.0
# 3      Apartamento          Higienópolis        1      0       0   800.0
# 4      Apartamento          Vista Alegre        3      1       0  1200.0
# ...            ...                   ...      ...    ...     ...     ...
# 22575  Apartamento                 Méier        2      0       0   900.0
# 22576    Quitinete                Centro        0      0       0   800.0
# 22577  Apartamento           Jacarepaguá        3      1       2  1800.0
# 22578  Apartamento  São Francisco Xavier        2      1       0  1400.0
# 22579  Apartamento                Leblon        2      0       0  3000.0
#
#        Condominio  IPTU  Valor Bruto  Valor m2
# 0           500.0  60.0       2260.0     42.50
# 1             NaN   NaN          NaN     70.00
# 2           390.0  20.0       1210.0     53.33
# 3           230.0   NaN          NaN     16.67
# 4             NaN   NaN          NaN     17.14
# ...           ...   ...          ...       ...
# 22575       490.0  48.0       1438.0     12.86
# 22576       350.0  25.0       1175.0     29.63
# 22577       800.0  40.0       2640.0     23.08
# 22578       509.0  37.0       1946.0     29.17
# 22579       760.0   NaN          NaN     42.86
#
# [22580 rows x 10 columns]

# %%
dados_new.drop(['Valor', 'Suites'], inplace = True)
dados_new
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 dados_new.drop(['Valor', 'Suites'], inplace = True)
#       2 dados_new
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['Valor', 'Suites'] not found in axis"

# %%
dados_new
# Out:
#               Tipo                Bairro  Quartos  Condominio  IPTU  \
# 0        Quitinete            Copacabana        1       500.0  60.0
# 1             Casa       Jardim Botânico        2         NaN   NaN
# 2      Apartamento                Centro        1       390.0  20.0
# 3      Apartamento          Higienópolis        1       230.0   NaN
# 4      Apartamento          Vista Alegre        3         NaN   NaN
# ...            ...                   ...      ...         ...   ...
# 22575  Apartamento                 Méier        2       490.0  48.0
# 22576    Quitinete                Centro        0       350.0  25.0
# 22577  Apartamento           Jacarepaguá        3       800.0  40.0
# 22578  Apartamento  São Francisco Xavier        2       509.0  37.0
# 22579  Apartamento                Leblon        2       760.0   NaN
#
#        Valor Bruto  Valor m2
# 0           2260.0     42.50
# 1              NaN     70.00
# 2           1210.0     53.33
# 3              NaN     16.67
# 4              NaN     17.14
# ...            ...       ...
# 22575       1438.0     12.86
# 22576       1175.0     29.63
# 22577       2640.0     23.08
# 22578       1946.0     29.17
# 22579          NaN     42.86
#
# [22580 rows x 7 columns]

# %%
dados_new.value_counts()
# Out:
# Tipo         Bairro           Quartos  Condominio  IPTU   Valor Bruto  Valor m2
# Apartamento  Ipanema          3        2200.0      495.0  8995.0       42.00       16
#              Barra da Tijuca  3        990.0       624.0  6114.0       38.46        8
#              Leblon           2        1100.0      200.0  5500.0       60.00        7
#              Barra da Tijuca  4        2300.0      345.0  11145.0      53.12        7
#                               3        1200.0      682.0  7382.0       25.94        7
#                                                                                    ..
#              Copacabana       3        1850.0      180.0  7030.0       35.71        1
#                                                    308.0  7458.0       41.09        1
#                                        1880.0      460.0  8840.0       35.14        1
#                                                    502.0  9582.0       39.13        1
# Quitinete    Vila Isabel      1        20.0        22.0   742.0        31.82        1
# Length: 14684, dtype: int64

# %%
dados_new['Quartos'].unique()
# Out:
# array([ 1,  2,  3,  5,  4,  0,  8, 14, 12, 10,  6,  7,  9, 32, 11],
#       dtype=int64)
